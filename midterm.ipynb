# %% [markdown]
# <a href="https://colab.research.google.com/github/ngHieu1501/midterm/blob/main/midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray, save
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import numpy as np

import os 
import numpy as np
from numpy import save
from keras.utils import to_categorical, load_img, img_to_array
from keras.models import Sequential,Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout, LeakyReLU
from keras.optimizers import SGD
import matplotlib.pyplot as plt

# %%
# !apt-get install git -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
#load folder datasets
folder = '/content/drive/MyDrive/flower'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in listdir(folder):
  output = None
  if file.startswith('apricot'):
    output = 0.0

  elif file.startswith('apricot '):
    output = 1.0
  elif file.startswith('daisy '):
    output = 2.0
  elif file.startswith('lotus '):
    output = 3.0
  elif file.startswith('purple '):
    output = 4.0
  elif file.startswith('rose '):
    output = 5.0

  if output is not None:
       
        image = load_img(os.path.join(folder, file), target_size=(200,200,3))
        image = img_to_array(image) 
        
        photos.append(image)
        labels.append(output)

#redefine type for array
photos = np.array(photos) 
labels = np.array(labels)

photos = photos.astype('float32')/255
# One-hot encode labels
labels = to_categorical(labels,5)
model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(200, 200,3)))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))



model.add(Conv2D(128,(3,3), padding = 'same'))
model.add(Activation('linear'))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))

sgd = SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov= True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=128, epochs=20, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d6af174a7ad> in <cell line: 5>()
#       3 #tiến hành tiền xử lý dữ liệu
#       4 photos, labels = list(), list()
# ----> 5 for file in listdir(folder):
#       6   output = None
#       7   if file.startswith('apricot'):
#
# NameError: name 'listdir' is not defined

# %% [markdown]
# # New Section

# %%
import os 
import numpy as np
from numpy import save
from keras.utils import to_categorical, load_img, img_to_array
from keras.models import Sequential,Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout, LeakyReLU
from keras.optimizers import SGD
import matplotlib.pyplot as plt
#load folder datasets
folder = '/content/drive/MyDrive/flower'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in os.listdir(folder):
    output = None
    if file.startswith('apricot'):
        output = 0      
    elif file.startswith('daisy'):
        output = 1
    elif file.startswith('lotus'):
        output = 2
    elif file.startswith('purple'):
        output = 3
    elif file.startswith('rose'):
        output = 4


    if output is not None:
       
        image = load_img(os.path.join(folder, file), target_size=(200,200,3))
        image = img_to_array(image) 
        
        photos.append(image)
        labels.append(output)

#Xác định kiểu cho mảng
photos = np.array(photos) 
labels = np.array(labels)

photos = photos.astype('float32')/255

labels = to_categorical(labels,5)
model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(200, 200,3)))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3), padding = 'same'))
model.add(Activation('linear'))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))

sgd = SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov= True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=128, epochs=10, verbose=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/10
# 2/2 [==============================] - 46s 14s/step - loss: 1.6186 - accuracy: 0.2021
# Epoch 2/10
# 2/2 [==============================] - 42s 12s/step - loss: 1.5572 - accuracy: 0.3457
# Epoch 3/10
# 2/2 [==============================] - 41s 13s/step - loss: 1.4953 - accuracy: 0.3457
# Epoch 4/10
# 2/2 [==============================] - 43s 12s/step - loss: 1.4124 - accuracy: 0.4255
# Epoch 5/10
# 2/2 [==============================] - 43s 13s/step - loss: 1.3405 - accuracy: 0.5745
# Epoch 6/10
# 2/2 [==============================] - 42s 13s/step - loss: 1.2688 - accuracy: 0.6489
# Epoch 7/10
# 2/2 [==============================] - 42s 14s/step - loss: 1.1603 - accuracy: 0.7181
# Epoch 8/10
# 2/2 [==============================] - 42s 13s/step - loss: 1.0935 - accuracy: 0.6543
# Epoch 9/10
# 2/2 [==============================] - 43s 13s/step - loss: 1.0249 - accuracy: 0.7074
# Epoch 10/10
# 2/2 [==============================] - 43s 15s/step - loss: 0.9099 - accuracy: 0.7500

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/flower/apricot (18).jpg', target_size =(200,200,3))
classes = ['apricot','daisy','lotus','purple','rose']
model.save('Hoa')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 158ms/step
# [[0.9598591  0.01936458 0.0043962  0.00161869 0.01476157]]
# 'apricot'

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/flower/purple (18).jpg', target_size =(200,200,3))
classes = ['apricot','daisy','lotus','purple','rose']
model.save('Hoa')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 154ms/step
# [[0.25144148 0.02004187 0.0760174  0.6064212  0.04607803]]
# 'purple'

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/flower/daisy (15).jpg', target_size =(200,200,3))
classes = ['apricot','daisy','lotus','purple','rose']
model.save('Hoa')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 155ms/step
# [[1.6020231e-02 7.1588004e-01 1.6426854e-01 1.0380912e-01 2.2043034e-05]]
# 'daisy'

# %%
#import thư viện
import os 
import numpy as np
from numpy import save
from keras.utils import to_categorical, load_img, img_to_array
from keras.models import Sequential,Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout, LeakyReLU
from keras.optimizers import SGD
import matplotlib.pyplot as plt
#load folder datasets
folder = '/content/drive/MyDrive/test_set'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in os.listdir(folder):
    output = None
    if file.startswith('Cuong'):
        output = 0      
    elif file.startswith('Danh'):
        output = 1
    elif file.startswith('Dien'):
        output = 2
    elif file.startswith('Khang'):
        output = 3
    elif file.startswith('Luan'):
        output = 4


    if output is not None:
       
        image = load_img(os.path.join(folder, file), target_size=(200,200,3))
        image = img_to_array(image) 
        
        photos.append(image)
        labels.append(output)

#Xác định kiểu cho mảng
photos = np.array(photos) 
labels = np.array(labels)

photos = photos.astype('float32')/255

labels = to_categorical(labels,5)
model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(200, 200,3)))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3), padding = 'same'))
model.add(Activation('linear'))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))

sgd = SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov= True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=128, epochs=10, verbose=1)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/10
# 1/1 [==============================] - 11s 11s/step - loss: 1.6155 - accuracy: 0.2000
# Epoch 2/10
# 1/1 [==============================] - 11s 11s/step - loss: 1.4871 - accuracy: 0.3111
# Epoch 3/10
# 1/1 [==============================] - 11s 11s/step - loss: 1.2411 - accuracy: 0.5111
# Epoch 4/10
# 1/1 [==============================] - 9s 9s/step - loss: 1.0491 - accuracy: 0.8444
# Epoch 5/10
# 1/1 [==============================] - 11s 11s/step - loss: 0.8462 - accuracy: 0.9778
# Epoch 6/10
# 1/1 [==============================] - 11s 11s/step - loss: 0.6020 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 9s 9s/step - loss: 0.4215 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 11s 11s/step - loss: 0.2733 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 11s 11s/step - loss: 0.1791 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 10s 10s/step - loss: 0.1100 - accuracy: 1.0000

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/test_set/Cuong (1).jpg', target_size =(200,200,3))
classes = ['Cuong', 'Danh', 'Dien', 'Khang', 'Luan']
model.save('Hoa')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 365ms/step
# [[0.96628267 0.00372881 0.00741401 0.00800774 0.0145668 ]]
# 'Cuong'

# %%
#import thư viện
import os 
import numpy as np
from numpy import save
from keras.utils import to_categorical, load_img, img_to_array
from keras.models import Sequential,Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout, LeakyReLU
from keras.optimizers import SGD
import matplotlib.pyplot as plt
#load folder datasets
folder = '/content/drive/MyDrive/tien'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in os.listdir(folder):
    output = None
    if file.startswith('10000'):
        output = 0      
    elif file.startswith('100000'):
        output = 1
    elif file.startswith('20000'):
        output = 2
    elif file.startswith('5000'):
        output = 3
    elif file.startswith('500000'):
        output = 4


    if output is not None:
       
        image = load_img(os.path.join(folder, file), target_size=(200,200,3))
        image = img_to_array(image) 
        
        photos.append(image)
        labels.append(output)

#Xác định kiểu cho mảng
photos = np.array(photos) 
labels = np.array(labels)

photos = photos.astype('float32')/255

labels = to_categorical(labels,5)
model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(200, 200,3)))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3), padding = 'same'))
model.add(Activation('linear'))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))

sgd = SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov= True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=128, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 27s 27s/step - loss: 1.6445 - accuracy: 0.1491
# Epoch 2/10
# 1/1 [==============================] - 22s 22s/step - loss: 1.0480 - accuracy: 0.6140
# Epoch 3/10
# 1/1 [==============================] - 24s 24s/step - loss: 1.0195 - accuracy: 0.6140
# Epoch 4/10
# 1/1 [==============================] - 24s 24s/step - loss: 0.9566 - accuracy: 0.6140
# Epoch 5/10
# 1/1 [==============================] - 22s 22s/step - loss: 0.9350 - accuracy: 0.6140
# Epoch 6/10
# 1/1 [==============================] - 24s 24s/step - loss: 0.9018 - accuracy: 0.6140
# Epoch 7/10
# 1/1 [==============================] - 22s 22s/step - loss: 0.8898 - accuracy: 0.6140
# Epoch 8/10
# 1/1 [==============================] - 24s 24s/step - loss: 0.8753 - accuracy: 0.6140
# Epoch 9/10
# 1/1 [==============================] - 22s 22s/step - loss: 0.8635 - accuracy: 0.6140
# Epoch 10/10
# 1/1 [==============================] - 24s 24s/step - loss: 0.8423 - accuracy: 0.6140

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/tien/50000 (9) (1).jpg', target_size =(200,200,3))
classes = ['10000', '100000', '20000', '5000', '500000']
model.save('midterm')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 332ms/step
# [[1.9919461e-01 1.3006385e-04 2.0075087e-01 5.9981602e-01 1.0849493e-04]]
# '5000'

# %%
#import thư viện
import os 
import numpy as np
from numpy import save
from keras.utils import to_categorical, load_img, img_to_array
from keras.models import Sequential,Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation, Dropout, LeakyReLU
from keras.optimizers import SGD
import matplotlib.pyplot as plt
#load folder datasets
folder = '/content/drive/MyDrive/do an'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in os.listdir(folder):
    output = None
    if file.startswith('banh mi'):
        output = 0      
    elif file.startswith('banh xeo'):
        output = 1
    elif file.startswith('Bun Rieu'):
        output = 2
    elif file.startswith('Hu tieu'):
        output = 3
    


    if output is not None:
       
        image = load_img(os.path.join(folder, file), target_size=(200,200,3))
        image = img_to_array(image) 
        
        photos.append(image)
        labels.append(output)

#Xác định kiểu cho mảng
photos = np.array(photos) 
labels = np.array(labels)

photos = photos.astype('float32')/255

labels = to_categorical(labels,5)
model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(200, 200,3)))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3), padding = 'same'))
model.add(Activation('linear'))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))

sgd = SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov= True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=128, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 10s 10s/step - loss: 1.7763 - accuracy: 0.0357
# Epoch 2/10
# 1/1 [==============================] - 10s 10s/step - loss: 0.8296 - accuracy: 0.5714
# Epoch 3/10
# 1/1 [==============================] - 7s 7s/step - loss: 0.6593 - accuracy: 0.6071
# Epoch 4/10
# 1/1 [==============================] - 8s 8s/step - loss: 0.6237 - accuracy: 0.6071
# Epoch 5/10
# 1/1 [==============================] - 6s 6s/step - loss: 0.6089 - accuracy: 0.7143
# Epoch 6/10
# 1/1 [==============================] - 8s 8s/step - loss: 0.5732 - accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 6s 6s/step - loss: 0.5208 - accuracy: 0.8929
# Epoch 8/10
# 1/1 [==============================] - 7s 7s/step - loss: 0.4588 - accuracy: 0.9286
# Epoch 9/10
# 1/1 [==============================] - 6s 6s/step - loss: 0.4093 - accuracy: 0.9643
# Epoch 10/10
# 1/1 [==============================] - 8s 8s/step - loss: 0.3983 - accuracy: 0.8571

# %%
from google.colab import drive
img = load_img('/content/drive/MyDrive/do an/hu tieu (3).jpg', target_size =(200,200,3))
classes = ['banh mi', 'banh xeo', 'bun rieu', 'bun rieu', 'hu tieu']
model.save('Hoa')


plt.imshow(img)
imgre = img_to_array(img)
imgre = imgre.reshape(1,200,200,3)
imgre = imgre.astype('float32')/255

predict = model.predict(imgre)
print(predict)
predict_classes =[np.argmax(element) for element in predict]
predict_classes
classes[predict_classes[0]]
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1/1 [==============================] - 0s 200ms/step
# [[5.0410849e-01 4.9566108e-01 4.3692940e-05 1.2953424e-04 5.7192632e-05]]
# 'banh mi'
